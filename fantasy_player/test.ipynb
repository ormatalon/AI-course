# %%
import numpy as np
arr = np.array([50, 100, 100, 93, 85, 80, 70, 90, 55, 500])

# %%
def rmse(arr):
    return np.sqrt(np.mean(arr**2))
rmse(arr)
# Out:
# 176.29492335288614

# %%
def mae(arr):
    return np.mean((np.abs(arr)))
mae(arr)
# Out:
# 122.3

# %%
np.abs(arr)
# Out:
# array([ 50, 100, 100,  93,  85,  80,  70,  90,  55, 500])

# %%
np.sqrt((25020+250000)/2)
# Out:
# 355.31676008879737

# %%
(50 + 500)/2
# Out:
# 275.0

# %%
2500/250000
# Out:
# 0.01

# %%
arr**2
# Out:
# array([  2500,  10000,  10000,   8649,   7225,   6400,   4900,   8100,
#          3025, 250000])
